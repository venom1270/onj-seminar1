# %%
import nltk
from bs4 import BeautifulSoup

# %% [markdown]
# ## Branje podatkov

# %%
def read_from_file():
    data = []
    f = open("../data/novice_doncic.txt", "r", encoding="utf-8")
    title = ""
    body = ""
    comments = []
    for line in f:
        line = line.replace("\n", "")
        if line == "":
            data.append( (title, body, comments) )
            title = ""
            body = ""
            comments = []
        elif title == "":
            title = line
        elif body == "":
            body = line
        else:
            comments.append(line)
    return data

# %%
news = read_from_file()

# %% [markdown]
# ## Lematizacija

# %% [markdown]
# Klic programa za lematizacijo. Lematiziramo naslove, telo novic in komentarje.
#
# 0: uspešno
#
# 1: neuspešno

# %%
import os
f_title = open("../ObeliksLatest/in_title.txt", "w", encoding="utf-8")
f_body = open("../ObeliksLatest/in_body.txt", "w", encoding="utf-8")
f_comment = open("../ObeliksLatest/in_comment.txt", "w", encoding="utf-8")
for n in news:
    f_title.write(n[0] + "\n\n")
    f_body.write(n[1] + "\n\n")
    for c in n[2]:
        f_comment.write(c + "\n\n")
    f_comment.write("DELIMITER\n\n")
f_title.close()
f_body.close()
f_comment.close()
os.chdir("../ObeliksLatest")
os.system("PosTaggerTag -lem:LemmatizerModel.bin -v -o -t in_title.txt TaggerModel.bin out_title.xml")
os.system("PosTaggerTag -lem:LemmatizerModel.bin -v -o -t in_body.txt TaggerModel.bin out_body.xml")
os.system("PosTaggerTag -lem:LemmatizerModel.bin -v -o -t in_comment.txt TaggerModel.bin out_comment.xml")
# Out:
# 0

# %% [markdown]
# Branje lematiziranih besed.

# %%
def read_lemmatized(path):
    f  = open(path, "r", encoding="utf-8").read()
    soup = BeautifulSoup(f, "lxml")
    lemmatized = []
    lemmas = soup.find_all("p")
    for i in range(0, len(lemmas), 1):
        lem = []
        for l in lemmas[i].find_all("w"):
            lem.append(l["lemma"])
        lemmatized.append(lem)
    #print(lemmatized)
    result = []
    for news in lemmatized:
        result.append(" ".join([str(x) for x in news]))
    return result

def read_lemmatized_comments(path):
    f  = open(path, "r", encoding="utf-8").read()
    soup = BeautifulSoup(f, "lxml")
    result = []
    lemmatized = []
    lemmas = soup.find_all("p")
    for i in range(0, len(lemmas), 1):
        lem = ""
        skip = False
        for l in lemmas[i].find_all("w"):
            #print(l["lemma"])
            if l["lemma"].lower() == "delimiter":
                result.append(lemmatized)
                lemmatized = []
                skip = True
            else:
                lem += l["lemma"] + " "
        if skip:
            skip = False
        else:
            lemmatized.append(lem)
    return result

titles_lemmatized = read_lemmatized("../ObeliksLatest/out_title.xml")
body_lemmatized = read_lemmatized("../ObeliksLatest/out_body.xml")
comments_lemmatized = read_lemmatized_comments("../ObeliksLatest/out_comment.xml")
print(len(titles_lemmatized))
print(len(body_lemmatized))
print(len(comments_lemmatized))
# Out:
# 7
# 7
# 7

# %% [markdown]
# ## Testiranje sentimenta

# %%
import os
def read_words(path):
    result = []
    f = open(path, "r", encoding="utf-8")
    for line in f:
        result.append(line.replace("\n", ""))
    os.chdir("../ObeliksLatest")
    #print("PosTaggerTag -lem:LemmatizerModel.bin -v -o -t " + path.split("ObeliksLatest/")[1] + " TaggerModel.bin out.xml")
    os.system("PosTaggerTag -lem:LemmatizerModel.bin -v -o -t " + path.split("ObeliksLatest/")[1] + " TaggerModel.bin out.xml")
    # Also lemmatize those words and include them in result
    lem = read_lemmatized("../ObeliksLatest/out.xml")
        
    return lem

positive_words = read_words("../ObeliksLatest/Sentiment/pozitivni_clean.txt") 
negative_words = read_words("../ObeliksLatest/Sentiment/negativni_clean.txt")
#positive_words = read_words("../ObeliksLatest/Sentiment/pozitivni_novi_preverjeni.txt") 
#negative_words = read_words("../ObeliksLatest/Sentiment/negativni_novi_preverjeni.txt")

# DUPLICATE CHECK - no output ok
for w in positive_words:
    if w in negative_words:
        print(w)

# %%
import math
# words - array of words
def sentiment_score(words):
    score = 0
    pos = 0
    neg = 0
    for w in words:
        if w in negative_words:
            score -= 1
            neg += 1
            #print("-" + w)
        if w in positive_words:
            score += 1
            pos += 1
            #print("+ " + w)
    #news_sentiment.append(100*score/len(words))
    #return int(100*score/len(words))
    #return math.log(pos + 0.5) - math.log(neg + 0.5)
    #if pos+neg==0:
    #    return 0
    #return score/float(pos+neg)
    return score

# %% [markdown]
# ### Izračunamo sentiment novic in izpišemo naslov novice z najnižjim sentimentom.

# %%
news_sentiment = []
for news_body in body_lemmatized:
    words = news_body.split(" ")
    score = sentiment_score(words)
    news_sentiment.append(score)
print(news_sentiment)
#print(body_lemmatized[:-3])
print("Najslabša novica: " + news[news_sentiment.index(min(news_sentiment))][0])
# Out:
# [9, 12, 17, 28, 4, 37, 13]
# Najslabša novica: Šov Dončića v Madridu, v 21 minutah 18 točk

# %% [markdown]
# ### Izračunamo sentiment komentarjev.

# %%
# COMMENT SENTIMENT
comment_sentiment = []
for cmnts in comments_lemmatized:
    c_sentiment = []
    for c in cmnts:
        score = sentiment_score(c.split(" "))
        c_sentiment.append(score)
    comment_sentiment.append(c_sentiment)
print(comment_sentiment)
#print(comments_lemmatized[-1][-6])
#print(comments_lemmatized[0][3])
# Out:
# [[0, 2, 3, 0, 2, 1, -1, 1, 1, -2, 0, 0, 0, 1, 5, 5, 1, 4, 4, 2], [0, 0, 4, -1, -1, 0, 2, 9, 2, 6, -2, 2, 6, 2, -3, 1, 0, 1, 0, 3], [-1, 0, -2, -1, 1, 1, 1, 2, 4, 0, 2, 2, 1, 8, 0, -1, 0, 0, 0, 1], [0, 0, 0, 1, 0, 2, 2, 0, 0, 2, -1, 3, 9, 4, 0, 2, 19, 7, 2, 8], [0, 0, 2, 1, 0, -1, 1, 0, 4, 1, 7, 0, 0, 1, 2, 4, -1, 3, 1, 2], [1, 0, 0, 0, 0, 0, 0, 5, 0, 0, 1, 0, 1, -1, 1, 0, 0, 6, 3, 1], [0, 2, 3, 0, 0, 0, 1, 3, 2, 0, 6, 0, 1, 0, 0, 0, 1, -1, -2, 1]]

# %% [markdown]
# ### Razvrstimo naslove novic po sentimentu

# %%
titles = [t for t,_,_ in news]
S = sorted(zip(news_sentiment,titles), reverse=True)
for s,t in S:
    print(str(s) + ": " + t)
# Out:
# 37: Reportaža iz Carigrada: Skok na letalo, do Turčije po zlato in domov
# 28: Cerar košarkarjem: Nagrada je bila namenjena vam, verjamem, da ste jo že prejeli
# 17: Dončić kot prvak Španije leti na nabor v New York
# 13: Foto in video - Iz tisočerih grl v Carigradu: "Mi, Slovenci!"
# 12: Dončić po odpovedi: "Bratje", nadaljujte, kar smo skupaj začeli. Kmalu bom z vami ...
# 9: Dončić po desetini sezone: ali pri Teličkih manjka predvsem kemija?
# 4: Šov Dončića v Madridu, v 21 minutah 18 točk

# %% [markdown]
# ### Razvrstimo naslove novic glede na sentiment komentarjev

# %%
comment_sentiment_aggregated = [sum(x)/len(x) for x in comment_sentiment]
S = sorted(zip(comment_sentiment_aggregated,titles), reverse=True)
for s,t in S:
    print(str((s)) + ": " + t)
# Out:
# 3.0: Cerar košarkarjem: Nagrada je bila namenjena vam, verjamem, da ste jo že prejeli
# 1.55: Dončić po odpovedi: "Bratje", nadaljujte, kar smo skupaj začeli. Kmalu bom z vami ...
# 1.45: Dončić po desetini sezone: ali pri Teličkih manjka predvsem kemija?
# 1.35: Šov Dončića v Madridu, v 21 minutah 18 točk
# 0.9: Reportaža iz Carigrada: Skok na letalo, do Turčije po zlato in domov
# 0.9: Dončić kot prvak Španije leti na nabor v New York
# 0.85: Foto in video - Iz tisočerih grl v Carigradu: "Mi, Slovenci!"

# %% [markdown]
# ### Najbolj negativni komentarji

# %%
comment_sentiment_all = []
for c in comment_sentiment:
    comment_sentiment_all += c
comments_all = []
for _,_,c in news:
    comments_all += c
S = sorted(zip(comment_sentiment_all,comments_all), reverse=False)
for s,t in S:
    print(str((s)) + ": " + t)
# Out:
# -3: Cini Minis@ Nekoga ki ne mara Slovenije in slovencev pa mora živeti tu, moraš tudi ti razumeti, da mora tip nositi težko breme s seboj !
# -2: Mamica in agent sta mu lepo tole napisala.  Glede na vse slovnične napake mislim, da je tole kar sam napisal. Upam, da to tudi resnično misli. Ker potem je treba res dolgoročno razmišljat in reprezentanco postavit tako, da bo ekipa ustrezala Lukatu. Edino vprašanje je kako se bomo brez njega uvrstil na temovanja.
# -2: Smešni so mi tisti, ki govorijo, da bosta v finalu dve Srbiji!
# -2: Čestitke Luka, v pomebnem trenutku super odločilna trojka ki je strla Baskonia! Srečno in brez poškodb v NBA! :)
# -2: šešerko, lih za show rabis kemijo. A misls, da so v evropi prijatelji? Mogocna kaksna ekipa, drugac je povsod isto. A mislis, da v evropi ne igrajo za denar. V kaksnem svetu eni zivite, edina razlika med NBA in evropo je, da je v NBAju vec denarja, in posledicno igrajo bolj kvalitetni igralci. Sezona je bolj naporna, zato se igralci sparajo za koncnico. To fantaziranje o evroligi, zgolj zato ker je evropska je ze prav smesno. V evroligi igras le zato, ker si preslab za NBA.
# -1: A mu ni 0 nerodn k tok smeš nasprotnike...Luka car
# -1: Danes index 16..skupno drugega najboljšega v končnici med vsemi...vseeno se bo kdo našel in ga kritiziral.  Luka ni robot. Igral je 11 mesecev (upoštevajoč priprave z reprezentanco od konca julija). Slab teden bo zlatu in zvinu gležnja že igral na super pokalu...vse do danes. Luka je slabo pripravljen in preveč je ane????
# 0: Na youtubu lahko najdete vrsto posnetkov, kjer Slovenci in Srbi skupaj navijajo in se veselijo. Taksno navijanje, medsebojno spostovanje in prijateljsko vzdusje mi pomeni skoraj se vec od te medalje. Sicer sem proti taksnim skandiranjem, a ne morem.mimo posnetka ko eni in drugi skupaj skacejo ob pesmi: "kdor ne skace ta je Hrvat"
# 0: Nas clovek, ce ga kups u lidlu je tako!
# 0: Ne nas lukat, brat!
# 0: Nič ne preseneča! Mulo je bil od nekdaj najboljši v vseh konkurencah, v katerih je nastopal. Še ko se je s 16 leti pojavil v članski konkurenci, je imel odlične indekse upoštevaje igralni čas. Letošnje leto bo njegovo!
# 0: POSTALI BOMO PRVAKI EVROPE!  http://www.publishwall.si/Mike.1968./pos t/122299/postali-bomo-prvaki-sveta
# 0: Pis ljubav bok!
# 0: Popoldne je bilo tako namenjeno predvsem posedanju v senci terase in nazdravljanju s hladnim pivom - v nasprotju s hladno deževno domovino je v Turčiji namreč pošteno pripekalo sonce in termometer je kazal kar okoli 30 stopinj  Se pravi če dobro razumem, pivo, sonce, basket, turistični ogledi in uživancija v sicet zelo osovraženi muslimanski Turčiji, ki je nihče noče v Evropi in je najbolj popljuvana država tukaj na forumu poleg Savdske Arabije,...  zanimivo,...
# 0: Prekletstvo slabih ekip, ki ima enega dobrega igralca. Vsak igralec se bori za čim boljšo pogodbo, saj se zaveda, da bo lahko vsak trenutek trejdan.
# 0: Prepeliču ni bilo prav nič treba te drame na Twitterju. S tem si ravno ne pridobiva simpatij.
# 0: Pri = prodal
# 0: Prle je car... https://ekipa.svet24.si/clanek/kosarka/r eprezentancna-kosarka/5acc880bb4022/prepelic
# 0: Rokomet ✔ Odbojka ✔ Košarka ✔ Nogomet ... nikoli
# 0: Sir Charles cisto resno,    Lukatu?????
# 0: Slovenci pokazimo kako se navija! Mamo to!
# 0: Slovenija bo zlata !!!
# 0: Več pa ni
# 0: Vsi za enega, eden za vse! Slo-veni-ja, Slo-veni-ja!
# 0: bratje, vi se uvrstite na SP, pa pridem igrati namesto vas (mogoče, če se javim na telefon)  realno so šanse za uvrstitev tako ali tako minimalne
# 0: el cartel  s kom pa bi se potem slikali in nabirali politične točke?
# 0: hahaha zmatran
# 0: https://sports.yahoo.com/important-nba-draft-update-luka-doncic-wants-jennifer-aniston-tiger-173921469.html
# 0: kaj je pa šel v cirkus nastopat....
# 0: kaj pa Antomi Tonček ?
# 0: kakšna kemija,kvalitete ni.že prva peterka je povprečna,klopi pa sploh ni. luka se bo kmalu naveličal te zgubarske mentalitete,saj je navajen lovorik
# 0: kruha in iger..
# 0: spet clutch trojka na eni nogi...hahaha...ta fant je nor THE DON MVP!!!!...upam, da se ga bo dans vseeno orng vlil, pa naj gre mačkast na draft...No.1 pick bo... bravo Luka!!
# 0: to je pa še nekaj bolj podlega kot razpisi na ministrstvu za gospodarstvo, k de nimajo tile pozerji že polnih riti
# 0: vse lepo in prav, ampak politikom bi pa prepovedal,da hodijo na take dogodke.  skoraj bi kozlal ko sem videl cerarja in brnabićevo.  prepovedat. oni nimajo nič skupnega z odrekanjem, znojem, borbo in medaljo.
# 0: zgleda bo letos ze spet ben simmons ROTY
# 0: Čestitke Hrvaški. Njihova soseda je novi evropski prvak v košarki.
# 0: čestitke košarkarjem in navijačem, navijačem  pa  ker niso povročili nobenega incidenta samo navijat so šli.tu v slo pa na podeželskih nogometnik tekmah povročijo pravo razdejanje
# 1: "Mavs so se pri tem odpovedali prihodnjemu izboru, tako da v primeru slabe sezone Teksašanov, bi Atlanta lahko še enkrat hitro izbirala. Atlanta je po odhodu Dennisa Schröderja potrebovala igralca, kot je Trae Young. Zagotovo je lahko menjava win-win za oba kluba,"  en popravek - pick je top5 protected tako da v primeru, da Mavsi izbirajo od 1 do 5 jim pick ostane. pick se prestavi v naslednja leta, 2021 je top3 protected, 2022 je nezavarovan...  iz ESPNa: "Dallas also sent a protected 2019 first-round pick to Atlanta. The pick is top-five protected the next two years, top-three protected in 2021 and '22 and unprotected the following year, according to Mavs president of basketball operations Donnie Nelson."
# 1: @vranek Ples, ni kvantni fizik, kosarkar je. In ker to dela vrhunsko, je to dovolj. In ne proba biti velik mislec in filozof, le tisto kar je. In sportnik je zaradi sebe, ne pa vas prevrtljivcev. Pac, zberi si koga drugega in navijaj po utecenih navadah ali kaj zelis. Nihce se ne bo na nos metal, da bo tebi fajn. V tvojih zeljah in navijaskih eskapadah.  Pač, to je moje mnenje, kaj me zdaj napadaš in se na nos mečeš ...
# 1: A dobi Real kako odškodnino ko gre Luka v NBA?
# 1: Adria je fino zaslužila na plečih športne evforije. Se je dalo priti z letalom tudi precej ceneje dol in nazaj, pod 200€, z le nekaj raziskovanja.
# 1: Blažič tudi zelo dobro. 20 pik, 7 skokov, 4 asistence.
# 1: Danes je imel Real šutersko odličen dan. V tem stilu je bil tudi Luka. Po fuzbalersko je v preigravanju pri še dva tunela med nogama. Bravo, le tako naprej!
# 1: Kaj bo Real čisto vse evropske prvake pokupil? Će bo res Vidmar vskočil in Prepelič pride pozimi, bo tam več Slovencev kot v Olimpiji
# 1: Kaj dela Luka, strašno, Llull je že priden navijač na klopi, s takima dvema igralcem pa moraš dejansko vse pregaziti.
# 1: Kaj imamo drzavljani od te kolajne?
# 1: Kam se splača it gledat na mobali?
# 1: Lepo bi bilo, če bi seveda pot v Evropi končal tako kot na prejšnji tekmi, ampak nora trojka na koncu, ko se je tekma lomila, pa po mojem mnenju je pokazal precejšnjo zrelost. Videl je, da mu ne gre in ni posiljeval svojega meta, ampak je raje predal žogo drugim, ki jim je danes šlo. Ne pa kot Llull recimo, ki si je prejšnjič vzel 14 metov in niti enega zadel.  Luka, hvala ti za neverjetno sezono in izjemne košarkaške predstave, prav mešane občutke imam, ker tekem več ne bom mogla spremljati v živo... Vso srečo v ZDA, ponosni smo nate!
# 1: Lepo je videt tako sportno vzdusje in medsebojno spostovanje. Vec takih navijacev in manj "drugacnih" (ki razbijajo in se pretepajo).
# 1: Luka bo naslednjič igral za reprezentanco junija 2020 na kvalifikacijskem turnirju za OI. Posledica? Jasno, uvrstitev na OI. In tam? Naskok na prvo slovensko medaljo v ekipnih športih!  Do takrat bo Luka že eden najboljših košarkašev na svetu.
# 19: ...tako bom dejal. Če so fantje igrali samo za nas in za Slovenijo, naslednjič več ne rabijo igrati. Igrali so zase, za nas in za Slovenijo. In za svoja prizadevanja in uspehe so  dobili  mnogo. Dobili so zlato, dobili so športno nesmrtnost, dobili so boljše izhodišče za višje in donosnejše pogodbe, dobili so nekaj denarja kot nagrado in dobili so zavidljive pokojnine. Fantje, če se samo preko denarja zrcali naše navdušenje nad vašimi predstavami, potem ste me pa tokrat prekleto razočarali. Vsi imate profesionalne pogodbe, za moje razumevanje so denarji, ki se plačujejo v profesionalnem športu nekatere  vsaj nekaj deset krat precenjene. Svoje principe pa si dajte potešiti v kakšni nematerialni zadevi. Nenazadnje so storili nekaj, kar bo v športu večina Slovencev le sanjala, dobili pa so temu primerno nekaj, kar bo lahko večina Slovencev v svojem življenju le sanjala. In dajmo se zavedati, da nismo Španija, nismo Francija, ampak smo Slovenija. Tokrat žal z vsem nisem na strani športnikov.

# %% [markdown]
# ## Clustering

# %% [markdown]
# Definiramo tokenizer metodo, ki razdeli stavek na posamezne besede.

# %%
import re
def tokenize(text):
    # First tokenize by sentence, then by word to ensure that punctuation is caught as it's own token.
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # Filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation).
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %% [markdown]
# Definiramo metodo, ki razdeli stavek na znakovni n-gram.

# %%
def character_ngram(text):
    n = 3
    result = []
    text = text.lower().replace(".", "").replace(",", "").replace("?", "").replace("!","")
    #text = text.replace(" ", "")
    for i in range(len(text)-n+1):
        result.append(text[i:i+n])
    return result

# %% [markdown]
# Računanje TFIDF matrike na dva načina - z uporabo tokenizer in ngram metod.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

tfidf_vectorizer_tokenizer = TfidfVectorizer(
                        max_df=0.8, 
                        max_features=200000,
                        min_df=0.2, 
                        stop_words='english', 
                        use_idf=True, 
                        tokenizer=tokenize, 
                        ngram_range=(1,3))

tfidf_vectorizer_cngram = TfidfVectorizer(
                        max_df=0.8, 
                        max_features=200000,
                        min_df=0.2, 
                        stop_words='english', 
                        use_idf=True, 
                        tokenizer=character_ngram, 
                        ngram_range=(1,3))

news_titles = [title for title,_,_ in news]

tfidf_matrix_tokenizer = tfidf_vectorizer_tokenizer.fit_transform(body_lemmatized) 
tfidf_matrix_cngram = tfidf_vectorizer_cngram.fit_transform(body_lemmatized) 

#print("TF-IDF matrix shape: {}".format(tfidf_matrix.shape))
#print(tfidf_matrix)


dist_tokenizer = 1 - cosine_similarity(tfidf_matrix_tokenizer)
dist_cngram = 1 - cosine_similarity(tfidf_matrix_cngram)
# Out:
# C:\Users\zigsi\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %% [markdown]
# Hierarhično razvrščanje (tokenize).

# %%
from scipy.cluster.hierarchy import ward, dendrogram
import matplotlib.pyplot as plt

# Define the linkage_matrix using ward clustering pre-computed distances.
linkage_matrix = ward(dist_tokenizer) 

fig, ax = plt.subplots(figsize=(15, 20)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=news_titles);

plt.tick_params(\
    axis= 'x',         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

# Uncomment the below to show or save the plot.
plt.show()
#plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters
plt.close()

# %% [markdown]
# Hierarhično razvrščanje (ngram).

# %%
# Define the linkage_matrix using ward clustering pre-computed distances.
linkage_matrix = ward(dist_cngram) 

fig, ax = plt.subplots(figsize=(15, 20)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=news_titles);

plt.tick_params(\
    axis= 'x',         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

# Uncomment the below to show or save the plot.
plt.show()
#plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters
plt.close()

# %%
from sklearn.cluster import KMeans

num_clusters = 5
km = KMeans(n_clusters=num_clusters)

km.fit(tfidf_matrix_tokenizer)

clusters = km.labels_.tolist()
print("Clusters: {}".format(clusters))
for i in range(num_clusters):
    print("CLUSTER " + str(i))
    for t,c in zip(news_titles, clusters):
        if c == i:
            print(t)
    print("")
# Out:
# Clusters: [1, 4, 1, 4, 4, 4, 1, 1, 1, 1, 2, 0, 0, 1, 1, 1, 1, 4, 0, 4, 2, 1, 1, 3, 2, 4, 1, 1, 4, 1, 0, 4, 2, 1, 1, 0, 0, 4, 2, 1, 1, 3, 0, 4, 0, 4, 4, 2, 0, 2, 0, 0, 1, 3, 4, 3, 2, 3, 4, 3, 2, 3]
# CLUSTER 0
# Pokol v baru v Kaliforniji izvedel 28-letni nekdanji marinec
# Trump novinarju ukazal, naj vrne mikrofon, in mu prepovedal vstop v Belo hišo
# Rihanna ostro proti temu, da Trump predvaja njene pesmi
# ZDA bodo iz sankcij na nakup iranske nafte izvzele osem držav
# Trump kljub nasprotovanju obiskal prizorišče strelskega napada v Pittsburghu
# Kanye se z besedami "izkoristili so me" distancira od politike
# ZDA: Število smrtnih žrtev napada v sinagogi se je povzpelo na 11
# ZDA: Najmanj osem mrtvih po strelskem napadu v sinagogi
# FBI v povezavi z bombnimi pošiljkami Trumpovim kritikom aretiral osumljenca
# Trump po bombnih pošiljkah poudarja "medijsko sovražnost". Paket tudi De Niru in Bidnu.
# Trump po eksplozivnih pošiljkah demokratom: "V teh časih se moramo združiti"
#
# CLUSTER 1
# Na Floridi znova volilni zapleti in novo štetje glasovnic
# Nafta v najdaljšem negativnem nizu v zadnjih 34 letih
# Alexandria Ocasio-Cortez: Socialistka, najmlajša kongresnica, nova zvezda demokratov
# Trumpov generalni tožilec povezan s podjetjem, ki je veterane opeharilo za prihranke
# Požari v Kaliforniji se širijo, devet mrtvih, številne pogrešajo
# Korejska senzacija BTS ob nastop zaradi sporne majice
# Trump: Volilni dan je bil izjemen; Sessions odstopil s položaja
# V Nevadi na volitvah zmagal že pokojni kralj bordelov
# Miro Cerar bo v tretje postal očka
# Demokratom večina v predstavniškem domu. Več prelomnih izvolitev.
# Trump: Mediji iz teh volitev delajo referendum o meni
# Če z vajeti spustiš podivjane pse, bodo na koncu pogrizeni vsi
# Napovedi: Konec prevlade republikancev v kongresu, demokratom večina v predstavniškem domu
# Applova tržna vrednost zdrsnila pod bilijon dolarjev
# Alec Baldwin klofnil možakarja, ki mu je "ukradel" parkirni prostor
# ZDA znova "nad" Kitajsko, tokrat zaradi kraje intelektualne lastnine
# V zaporu ubili razvpitega gangsterja Jamesa Bulgerja
# Ali Jair Bolsonaro, "brazilski Trump", res prinaša konec demokracije v Braziliji?
# Brazilci so za predsednika izbrali populističnega Bolsonara
# Japonski premier bo obiskal Peking. Odnosi med državama se izboljšujejo.
#
# CLUSTER 2
# Trumpova administracija prepovedala azil za nezakonite pribežnike
# Predsednika Hondurasa in Gvatemale želita ustaviti prebežnike
# Prve skupine migrantov iz Srednje Amerike prispele v Ciudad de Mexico
# Trump grozi s streljanjem na prebežnike in govori o "šotorskih mestih"
# Trump govori o "invaziji na ZDA" in na mejo pošilja 5.200 vojakov
# Mehika migrantom iz konvoja, ki bi zaprosili za azil, ponuja dovoljenje za delo
# Trump bi prebežnikom preprečil vstop v ZDA kar z izvršnim ukazom
# Trump bo zaradi karavane prebežnikov ukinil pomoč srednjeameriškim državam
# Begunsko karavano na poti v ZDA zaustavili na meji med Mehiko in Gvatemalo
#
# CLUSTER 3
# Hašokdžijeva sinova zahtevata vrnitev očetovega trupla
# Savdski zunanji minister: "Svetloba" Savdske Arabije proti "temi" Irana
# Savdski kronski princ umor Hašokdžija označil za "bolečega in gnusnega"
# Erdogan: Imamo dokaze, da je bil umor načrtovan
# Savdska Arabija: Umor novinarja je bil "strašna napaka"
# Ameriški PEN vložil tožbo proti Donaldu Trumpu
# Turčija napoveduje razkritje podrobnosti preiskave Hašokdžijeve smrti
#
# CLUSTER 4
# Macron in Angela Merkel posvarila pred nacionalizmom
# Macron in Angela Merkel na kraju podpisa premirja pred 100 leti potrdila spravo
# Manjša vloga ZDA v savdskem bombardiranju Jemna
# Trump Macronov poziv po evropski vojski označil za "žaljivega"
# Državljanstvo – naj bo glavno merilo rod staršev ali država rojstva?
# Macron želi evropsko vojsko za obrambo pred Rusijo in ZDA
# "Smrt Ameriki" - Iranci protestirajo proti novim sankcijam
# V Iranu stekla proizvodnja "stoodstotno domačih" vojaških letal
# Brazilija bo veleposlaništvo iz Tel Aviva preselila v Jeruzalem
# "Načelni pragmatizem" EU-ja v senci milijardnih orožarskih poslov s Savdsko Arabijo
# Or Rabinowitz: Izraelu bolj ustreza šibki Asad pod ruskim nadzorom kot pa radikalne sunitske milice ali Iran
# Foto: Kako noč čarovnic praznujejo žirafe, bolivijske opice in gorile
# Kitajska in Japonska krepita stike in sklepata posle
# Trump in Putin 11. novembra v Parizu znova "iz oči v oči"
# Rusija: Odstop ZDA od pogodbe o jedrskih raketah "zelo nevaren korak"

# %% [markdown]
# Če poženemo K-Means s tremi clustri, vidimo, da novice v grobem razvrsti v tri smeselne kategorije: volitve, migranti, umori.
#
# Pet clustrov: volitve, migranti, svet, Savdska Arabija/Iran, umori.
#
# Če uporabimo n-gram, so clustri bolj izraziti in neuravnoteženi. (Rezultati niso vedno enaki).

# %% [markdown]
# Poglejmo še sentiment novic posameznega clustra.

# %%
for i in range(num_clusters):
    print("CLUSTER " + str(i))
    cluster_sentiment = 0
    for t,s,c in zip(news_titles, news_sentiment, clusters):
        if c == i:
            cluster_sentiment += s
    print("Sentiment: " + str(cluster_sentiment))
# Out:
# CLUSTER 0
# Sentiment: 95
# CLUSTER 1
# Sentiment: 360
# CLUSTER 2
# Sentiment: 95
# CLUSTER 3
# Sentiment: 190
# CLUSTER 4
# Sentiment: 443

# %% [markdown]
# Enako, le da gledamo sentiment komentarjev.

# %%
comment_sentiment_aggregated = [sum(x)/len(x) for x in comment_sentiment]
for i in range(num_clusters):
    print("CLUSTER " + str(i))
    cluster_sentiment = 0
    for t,s,c in zip(news_titles, comment_sentiment_aggregated, clusters):
        if c == i:
            cluster_sentiment += s
    print("Sentiment: " + str(cluster_sentiment))
# Out:
# CLUSTER 0
# Sentiment: 7.392857142857142
# CLUSTER 1
# Sentiment: 25.401968864468866
# CLUSTER 2
# Sentiment: 12.350000000000001
# CLUSTER 3
# Sentiment: 5.975
# CLUSTER 4
# Sentiment: 21.27777777777778
